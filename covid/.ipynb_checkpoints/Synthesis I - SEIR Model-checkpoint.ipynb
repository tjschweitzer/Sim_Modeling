# %% [markdown]
# # Synthesis Project I: SEIR Model
#
# In this project, you will apply much of what we've already done in this class to address a contemporary issue; *when will we reach COVID-19 herd immunity?* We will estimate the time this occurs using a number of tools that you are now familiar with,
#
# * object-oriented Python programming,
# * solving ordinary differential equations,
# * MCMC methods for uncertainty quantification and
# * management and visualization of intermediate volumes of data.
#
# In addition to these now familiar tools, we will be learning more about *optimization* in the context of *inverse modeling*.
#
# ## Basis
# The basis for our work can be found in [this paper](https://www.nature.com/articles/s41598-020-77628-4.pdf). Here, we learn that a relatively simple set of ODEs can be solved to model the propagation of an infectious disease through a human population. This model is appropriate for a disease that has a period where people are infected, contagious, but asymptomatic. We use the term "exposed" for this group of people. The key concept in the paper is best related through the rate of change equations:
#
# $$\begin{align}
# \frac{dS}{dt} &= -\beta S ( I + qE) / N\\
# \frac{dE}{dt} &=  \beta S ( I + qE) / N - \frac{E}{\delta} \\
# \frac{dI}{dt} &=  \frac{E}{\delta} - \frac{I}{\gamma}\\
# \frac{dR}{dt} &=   \frac{I}{\gamma}
# \end{align}$$
#
# Where $S$ is the susceptible population, $E$ the exposed, $I$ the infected, and $R$ the recovered. Observe that every term on the right hand side is repeated twice - once negative and once positive. This reflects that the dynamics take people away from one population and puts them into another. For example, $-\beta S ( I + qE) / N$ is taking susceptible people and moving them to the exposed population. The rate this is occurring is $\beta$ and both infected and exposed can infect a susceptible. However, exposed are $q$ less likely to infect a susceptible because they aren't sneezing or coughing. $N$ is the population of the unit being modeled (state or country), and dividing by $N$ makes the calculations independent of population and working on population *fractions*. $\delta$ is the time between exposure and symptoms, and $\gamma$ the time people are sick.
#
# Of course, nothing so high-profile as a Nature paper can ever be so easy. Much of the paper is committed to compartmentalizing these equations by age. However, for our purposes, the above is sophisticated enough. Indeed, one can reasonably ask if the compartmental models don't just introduce more parameters that are uncertain and produce *over-fitting*.
#
# ### Problem 0: Parameters
# Read the paper carefully to find acceptable values for the parameters. Of critical interest will be:
# * $\beta$ the infection rate
# * $\delta$, the time between exposure and infection
# * $\gamma$, the time of infection
# * $q$, the decrease in infection rate that exposed individuals have when compared to the infected.
# * $d$ the death rate, or fraction of infected that die instead of recover.
#
# Create a dictionary or other data type to store these parameters in an effective way, such that code retrieving data is easy to read, and changes to parameter values are possible.
#
#
# ### Problem 1: Coding up the RHS
# Let's continue our assignment by coding up the right hand side of the above equations.

# %%
"""
Create the parameters data structure. Determine reasonable initial values by studying the paper.
"""
import numpy as np
def SEIR(t,y,p):
    """
    Accepts the state of the system as:
    y[0] = Suseptable population - never impacted by the disease
    y[1] = Exposed population - has the disease, but not yet manifesting symptoms
    y[2] = Infected population - has the disease, and symptoms
    y[3] = Recovered population - has recovered from the disease, and is no longer suseptable
    
    This function returns the time deriviative of the state, dydt, and uses a dictionary 
    of parameters p.
    """
    beta = p['beta'][t]    #.1-.8
    q = p['q']         
    delta = p['delta']  
    gamma = p['gamma']
    N = p['n']
    
    S,E,I,R =  y[:4]
    
    dS = - beta*S*(I+q*E)/N
    
    E_d = E/delta
    
    dE = -dS - E_d
    
    
    dI = E_g - I/gamma
    dR = I/gamma
    
    
    return np.array([dS,dE,dI,dR])

# %% [markdown]
# ## Inverse Modeling
#
# In this assignment we will employ a powerful method called *inverse modeling*. You are now accustomed  to doing *forward-modeling* - initial values and parameters are set, and and you are interested in future states. The bullet problem is a great example of this. So is n-body. The results of interest is found throughout or at the end of the simulation. The business of simulation is starting with what you know, and getting from the beginning to the end.
#
# In inverse modeling, you are going to run a model as you did before, but instead of focusing solely on the results, you are going to focus on the input parameters that give particular results. Said more specifically:
#
# * ***forward model*** - set the inputs and study the output.
# * ***inverse model*** - determine the inputs required to minimize the difference between outputs and observations, hence *determining unknown inputs*.
#
# Differences between model and observation can be computed with sum square error or another error metric. Care must be taken to ensure model outputs are directly comparable to data in terms of both observation, and reconciliation of state.
#
# As it happens, you've done a simple inverse problem already. You had to find the angle to fire the gun in order to have the bullet hit zero at some range, often 200 meters. In that problem, the angle would be the *control parameter*, and the forward model was your friction model applied to a 2D projectile traveling in a gravitational field. The error was simply looking at if the zero was reached at the desired distance.
#
# As with many new ideas, examples help. Now, let's apply inverse modeling to COVID-19.
#
# ### Example COVID-19
#
# In the global pandemic, there are some things that we know we don't know and others that we might know. For example, it's very hard to know the number of individuals infected. We don't have enough testing, and too many people are asymptomatic or don't report their illness. That's a shame, because the infected are a state variable.
#
# But, we probably know how many died. Death is serious business, and tends to be recorded accurately. Of course, there are some questions, many of the dead have multiple medical issues. But, for the sake of this assignment, let's assume we know COVID-19 deaths in the US.
#
# However, the number of infected is a state variable, and not deaths. So, we need to make some adjustments there. Let's figure out how to make death a state variable.
#
# As to the inverse model, and the control parameter; look back at those SEIR equations. What might be a parameter that we can adjust to bring the state into consistency with observations of death? We are looking for something that is not well known, but critical to disease dynamics.
#
# $\beta$, or the infection rate is a good place to look. This is how easily the disease spreads from person to person. It is a number that is inherent to the disease; a reflection of how much virus is in the sinuses, how often, and how forcefully people cough or sneeze, how long lived the virus is in the open environment, outside a body, etc.
#
# But, $\beta$ can also be lowered by *policies*. So called non-pharmaceutical interventions. Wearing a mask lowers $\beta$. Social distancing lowers $\beta$. Closing restaurants and bars, and beaches. Policies are clearly having a big impact on $\beta$.
#
# So, our inverse parameter should be time dependent, $\beta(t)$, reflecting how people move into and out of compliance with non-pharmaceutical interventions. We will make no assumptions about the way this curve varies in time.
#
# It's worth noting that epidemiologists don't talk about $beta$. Rather, they speak of $R_o$, which has a very clear interpretation: it is the number of cases that occur per case. How many people, on average, become infected from an infected person. In our model, it is the product $\beta \gamma$ (not $\beta (\gamma + qE)$ for reasons I'm not sure I understand), where $\gamma$ is the time a person is infectious, and $E$ the time they are exposed, shedding virus,and asymptomatic. $q$ reflects how much less infectious they are during this initial period.
#
# $R_o$ is a good parameter to think about because if it is less than 1, the disease is on its way out.The infected exponentially decay. If it is greater than 1, then the disease is propagating, *exponentially*.
#
# So, let's approach the problem as follows:
#
# * Death rates will be compared to the model output and minimized.
# * The parameter $\beta$ will be used to adjust the model and minimize differences with observation.
# * The death-rate will also be adjusted to meet the observations.
# * $\beta$ will be converted to $R_o$ to make results easier to interpret.
#
# #### Problem 2: Adding the dead to the ODEs
# At this stage - there is a lot to understand, but not a lot to do. As a test of your understanding of the ODEs, add the death rate to create a 5th state variable, the dead $D$. Express this as you do the other variables, as a rate of change computed from fractions of the population. You will have to introduce another key variable, the death rate, which is multiplied by the appropriate populations. Hint - death is a morbid form of recovery.
#
# #### Problem 3: Using a Polynomial for $\beta(t)$
#
# The parameter $\beta(t)$ will be time dependent and adjusted to meet observations. So, how to get a smoothly varying function that reflects the changes that have occurred in the infectiousness?
#
# Let's use a `numpy Polynomial` object. So there is some consistency in our results, make it a **6th order** polynomial. Below, master the instantiation of the object, and how an array of coefficients can be used to change the coefficients in the `Polynomial` object.
#
# Place the polynomial into the parameters data structure.

# %%
import pandas as pd
from solve_ode import *
from scipy.integrate import solve_ivp
import math
import numpy as np
class SEIR_class:
    
    def __init__(self):
        self.cache = {}
        covid_filename = 'Provisional_COVID-19_Death_Counts_by_Week_Ending_Date_and_State.csv'
        pop_filename = 'Population.csv'
        self.death_data = {}
        self.population_dict = {}
        
        week_sring = '%M/%D/%Y'
        raw_data = pd.read_csv(covid_filename,header=0,parse_dates=['Start Date','End Date'], date_parser= self.cached_date_parser)
        
        for i in range(len(raw_data)):
            
            state = raw_data.iloc[i]['State']
            s_date = raw_data.iloc[i]['Start Date']
            e_date = raw_data.iloc[i]['End Date']
            row_death =  raw_data.iloc[i]['Pneumonia and COVID-19 Deaths']
            if math.isnan(row_death):
                row_death = 0
                
            if state not in self.death_data:
                self.death_data[state] = {'dates':[],
                                         'deaths':[]}
            self.death_data[state]['deaths'].append(row_death)
            self.death_data[state]['dates'].append(s_date)
        pop_data = pd.read_csv(pop_filename, sep=',',header=0)
        
        for i in range(len(pop_data)):
            state = pop_data.iloc[i]['Area']
            population = pop_data.iloc[i]['2019']
            if state[0] =='.':
                state=state[1:]
            self.population_dict[state] = population
#             print(state, population)
    

    def cached_date_parser(self,s):
        if s in self.cache:
            return self.cache[s]
        dt = pd.to_datetime(s, format='%m/%d/%Y')
        self.cache[s] = dt
        return dt 
    
    def set_parameter(self,location="",q=1,delta =1, gamma =1 ,\
                      death_rate =1 ,Eo_frac = 1, degree = 1, \
                      coefs = 1, beta_o = 1):
        """
        This simple routine simply sets the parameters for the model. 
        Note they are not all unity, I want you to figure out the
        appropriate parameter values.
        location - location to be modeled
        q - the attenuation of the infectivity, gamma in the population that is E
        delta - the length of time of asymptomatic exposure
        gamma - the length of time of infection
        death_rate - the fraction of infected dying
        Eo_frac    - a small number that is multiplied by the population to give the initially exposed
        degree     - degree of polynomial used for beta(t)
        coeffs     - the set of initial coefficients for the polynomial, None in many cases
        beta_o     - a constant initial value of beta, will be changed in the optimization
        """   
        self.q = q
        self.delta = delta
        self.death_rate=death_rate
        self.Eo_frac = Eo_frac
        self.degree = degree
        self.coefs=coefs
        self.gamma = gamma

        self.beta_function = np.poly1d(self.coefs)
        perams = {}
        perams['q'] =  self.q
        perams['delta'] =  self.delta
        perams['death_rate'] =  self.death_rate
        perams['Eo'] =  self.Eo_frac
        perams['gamma'] = self.gamma
        perams['n'] = self.N 
        self.perams = perams

    def set_location(self,location):
        """
        Given a location string, this function will read appropriate 
        data files to set the population parameter N and
        data fields within the SEIR object appropriate time series of
        deaths from COVID-19.
        """
        if location not in self.death_data:
            print('Invalid Location')
            return
        self.location = location
        self.start_date = min(self.death_data[location]['dates'])
        self.end_date = max(self.death_data[location]['dates'])
        self.total_days = (self.end_date - self.start_date).days
        self.N = float(self.population_dict[location].replace(",", ""))
        print(type(self.total_days))
        
        
        
    def get_SSE(self,opt_params):
        """
        The hardest working routine - will 
        1. accept a set of parameters for the polynomial coefficients and the death rate
        2. run the SEIR model using the ODE solver, solve_ivp
        3. return an Sum Square Error by comparing model result to data.
        """
        self.y0 = np.array([self.N*(1-self.Eo_frac),self.N*(self.Eo_frac),0,0,0],dtype=np.float)
        sol = solve_ivp(SEIR, [0.,self.total_days],self.y0)
        
        
        
    def plot_results(self):
        ts = pd.Series(self.death_data[self.location]['deaths'],
                       index=pd.date_range(self.start_date,self.end_date,periods=len(self.death_data[self.location]['dates'])))
                                           

        ts.plot()
        
        """ 
        create a 4 panel plot with the following views:

        * Deaths modeled and deaths observed as a function of time.
        * 𝑅𝑜  as a function of time.
        * The susceptable, infected and recovered populations as a function of time.
        * The fraction of the population that has recovered as a function time.
        Observe that by passing a list of dates you can get a nicely formated time axis.
        """

# %%
app = SEIR_class()
app.set_location('Montana')
app.set_parameter(q=.5,delta = 6, gamma = 10, Eo_frac=.0002)
app.get_SSE(app.perams)
app.plot_results()
# Out:
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-a9ced66b23ca> in <module>
#       2 app.set_location('Montana')
#       3 app.set_parameter(q=.5,delta = 6, gamma = 10, Eo_frac=.0002)
# ----> 4 app.get_SSE(app.perams)
#       5 app.plot_results()
#       6
#
# <ipython-input-110-aa515547f7b8> in get_SSE(self, opt_params)
#     110         """
#     111         self.y0 = np.array([self.N*(1-self.Eo_frac),self.N*(self.Eo_frac),0,0,0],dtype=np.float)
# --> 112         sol = solve_ivp(SEIR, [0.,self.total_days],self.y0)
#     113
#     114
#
# ~/.local/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     540         method = METHODS[method]
#     541
# --> 542     solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     543
#     544     if t_eval is None:
#
# ~/.local/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in __init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92         self.max_step = validate_max_step(max_step)
#      93         self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94         self.f = self.fun(self.t, self.y)
#      95         if first_step is None:
#      96             self.h_abs = select_initial_step(
#
# ~/.local/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     136         def fun(t, y):
#     137             self.nfev += 1
# --> 138             return self.fun_single(t, y)
#     139
#     140         self.fun = fun
#
# ~/.local/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      18
#      19     def fun_wrapped(t, y):
# ---> 20         return np.asarray(fun(t, y), dtype=dtype)
#      21
#      22     return fun_wrapped, y0
#
# TypeError: __init__() takes 1 positional argument but 3 were given

# %%
print(app.y0)

# %%
def SEIR(t,y,p):
    """
    Accepts the state of the system as:
    y[0] = Suseptable population - never impacted by the disease
    y[1] = Exposed population - has the disease, but not yet manifesting symptoms
    y[2] = Infected population - has the disease, and symptoms
    y[3] = Recovered population - has recovered from the disease, and is no longer suseptable
    y[4] = Dead population - these are the people that have died from COVID-19
    
    This function returns the time deriviative of the state, dydt, and uses a dictionary 
    of parameters p.
    """
    
"""
Experiment with the Polynomial objects in numpy - they require some playing with to get the syntax correct.
"""

# %% [markdown]
# ### Critical Methods
#
# OK, by now writing the RHS was probably pretty simple for you. Now let's write some infrastructure that will make this assignment doable. Each of the following should be a method, perhaps with some helper methods. I suggest an object oriented approach, as you will need to interrogate this object with many different parameters.
#
# #### Problem 4: Acquire data
# Many of the data files that drive this simulation will be in `csv` format. Two important ones are [death counts](https://www.cdc.gov/nchs/nvss/vsrr/covid19/index.htm) and [population estimates](https://www.census.gov/data/tables/time-series/demo/popest/2010s-national-total.html#par_textimage_2011805803).
#
# Data acquisition facilities can and should live outside the class storing the ODE and tools for solving it. It should return data for a named location. Methods should return `numpy` arrays of numbers and lists of `datetime` objects.
#
# Before starting, familiarize yourself with `datetime` and `csv` Python modules, as they will be used here.
#
# #### Problem 5: Set location
# This method *will* live in the object that has the following functions. Think of location as a key parameter that sets data fields. Write a function that uses the data acquisition tools to get the data needed. Think carefully about the need to reconcile days since the model started running (that's the model output) with the calendar day, which you get in the data set.
#
# #### Problem 6: Set parameters
# While you will set the key parameters upon initialization of the simulation, it will also be important that you can change them and re-run. Add a method that performs the typical tasks of the `__init__` method and sets parameters.
#
# #### Problem 7: Get the SSE
# This function can be called to numerically solve the system of ODEs and compare it to the data, finding the sum square error (SSE). Rather than use your own ODE solvers, use the `scipy.integrte.solve_ivp` module. The differences in signature are mostly superficial and this should be a quick change.
#
# The method will need access to the current set of parameters for the model.
#
# This method should then compare the deaths computed to the deaths observed. This is mostly easy so long as you remember:
#
# * The `datetime` objects can be differenced to get the number of days, so find number of days from the first day you have data for each data point. This will make the ODE output directly comparable to the observations.
# * The `solve_ivp` can be given a `t_eval` list that specifies when you need to have a state estimate. Use this to make sure the model output can be directly compared to the observations.
# * The model will return the cumulative sum of the deaths. The data is reported in deaths per week. Make necessary adjustments so that you compare deaths per week.
#
# This function should return the sum square error, a single scalar value.
#
# #### Problem 8: Plot results
#
# At the very least, create a 4 panel plot with the following views:
# * Deaths modeled and deaths observed as a function of time.
# * $R_o$ as a function of time.
# * The susceptable, infected and recovered populations as a function of time.
# * The fraction of the population that has recovered as a function time.
#
# Observe that by passing a list of dates you can get a nicely formated time axis.

# %%
def set_parameter(self,location="",q=1,delta =1, gamma =1 ,\
                  death_rate =1 ,Eo_frac = 1, degree = 1, \
                  coefs = 1, beta_o = 1):
     """
     This simple routine simply sets the parameters for the model. 
     Note they are not all unity, I want you to figure out the
     appropriate parameter values.
     location - location to be modeled
     q - the attenuation of the infectivity, gamma in the population that is E
     delta - the length of time of asymptomatic exposure
     gamma - the length of time of infection
     death_rate - the fraction of infected dying
     Eo_frac    - a small number that is multiplied by the population to give the initially exposed
     degree     - degree of polynomial used for beta(t)
     coeffs     - the set of initial coefficients for the polynomial, None in many cases
     beta_o     - a constant initial value of beta, will be changed in the optimization
     """   

     pass


def set_location(self,location):
    """
    Given a location string, this function will read appropriate 
    data files to set the population parameter N and
    data fields within the SEIR object appropriate time series of
    deaths from COVID-19.
    """
    pass

def get_SSE(self,opt_params):
    """
    The hardest working routine - will 
    1. accept a set of parameters for the polynomial coefficients and the death rate
    2. run the SEIR model using the ODE solver, solve_ivp
    3. return an Sum Square Error by comparing model result to data.
    """
def plot_results(self):
    """
    create a 4 panel plot with the following views:

    * Deaths modeled and deaths observed as a function of time.
    * 𝑅𝑜  as a function of time.
    * The susceptable, infected and recovered populations as a function of time.
    * The fraction of the population that has recovered as a function time.
    Observe that by passing a list of dates you can get a nicely formated time axis.
    """
# Out:
# United States {datetime.datetime(2019, 12, 29, 0, 0): 1.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 2.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 1.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 2.0, datetime.datetime(2020, 2, 23, 0, 0): 5.0, datetime.datetime(2020, 3, 1, 0, 0): 3307.0, datetime.datetime(2020, 3, 8, 0, 0): 29.0, datetime.datetime(2020, 3, 15, 0, 0): 251.0, datetime.datetime(2020, 3, 22, 0, 0): 1439.0, datetime.datetime(2020, 3, 29, 0, 0): 4773.0, datetime.datetime(2020, 4, 5, 0, 0): 7236.0, datetime.datetime(2020, 4, 12, 0, 0): 7319.0, datetime.datetime(2020, 4, 19, 0, 0): 6615.0, datetime.datetime(2020, 4, 26, 0, 0): 5519.0, datetime.datetime(2020, 5, 3, 0, 0): 4716.0, datetime.datetime(2020, 5, 10, 0, 0): 3786.0, datetime.datetime(2020, 5, 17, 0, 0): 2979.0, datetime.datetime(2020, 5, 24, 0, 0): 2488.0, datetime.datetime(2020, 5, 31, 0, 0): 2149.0, datetime.datetime(2020, 6, 7, 0, 0): 1863.0, datetime.datetime(2020, 6, 14, 0, 0): 1606.0, datetime.datetime(2020, 6, 21, 0, 0): 1555.0, datetime.datetime(2020, 6, 28, 0, 0): 2002.0, datetime.datetime(2020, 7, 5, 0, 0): 2711.0, datetime.datetime(2020, 7, 12, 0, 0): 3450.0, datetime.datetime(2020, 7, 19, 0, 0): 3959.0, datetime.datetime(2020, 7, 26, 0, 0): 4073.0, datetime.datetime(2020, 8, 2, 0, 0): 3978.0, datetime.datetime(2020, 8, 9, 0, 0): 3672.0, datetime.datetime(2020, 8, 16, 0, 0): 3212.0, datetime.datetime(2020, 8, 23, 0, 0): 2880.0, datetime.datetime(2020, 8, 30, 0, 0): 2504.0, datetime.datetime(2020, 9, 6, 0, 0): 2290.0, datetime.datetime(2020, 9, 13, 0, 0): 2046.0, datetime.datetime(2020, 9, 20, 0, 0): 2108.0, datetime.datetime(2020, 9, 27, 0, 0): 2029.0, datetime.datetime(2020, 10, 4, 0, 0): 2348.0, datetime.datetime(2020, 10, 11, 0, 0): 2437.0, datetime.datetime(2020, 10, 18, 0, 0): 2720.0, datetime.datetime(2020, 10, 25, 0, 0): 3218.0, datetime.datetime(2020, 11, 1, 0, 0): 25002.0, datetime.datetime(2020, 11, 8, 0, 0): 4991.0, datetime.datetime(2020, 11, 15, 0, 0): 6250.0, datetime.datetime(2020, 11, 22, 0, 0): 7429.0, datetime.datetime(2020, 11, 29, 0, 0): 8776.0, datetime.datetime(2020, 12, 6, 0, 0): 9839.0, datetime.datetime(2020, 12, 13, 0, 0): 10757.0, datetime.datetime(2020, 12, 20, 0, 0): 11272.0, datetime.datetime(2020, 12, 27, 0, 0): 12208.0, datetime.datetime(2021, 1, 3, 0, 0): 12911.0, datetime.datetime(2021, 1, 10, 0, 0): 12806.0, datetime.datetime(2021, 1, 17, 0, 0): 11753.0, datetime.datetime(2021, 1, 24, 0, 0): 10128.0, datetime.datetime(2021, 1, 31, 0, 0): 8615.0, datetime.datetime(2021, 2, 7, 0, 0): 6692.0, datetime.datetime(2021, 2, 14, 0, 0): 5380.0, datetime.datetime(2021, 2, 21, 0, 0): 4116.0, datetime.datetime(2021, 2, 28, 0, 0): 3064.0, datetime.datetime(2021, 3, 7, 0, 0): 2244.0, datetime.datetime(2021, 3, 14, 0, 0): 1564.0, datetime.datetime(2021, 3, 21, 0, 0): 1030.0, datetime.datetime(2021, 3, 28, 0, 0): 375.0, datetime.datetime(2020, 1, 1, 0, 0): 262243.0, datetime.datetime(2020, 2, 1, 0, 0): 8.0, datetime.datetime(2020, 4, 1, 0, 0): 28307.0, datetime.datetime(2020, 5, 1, 0, 0): 15872.0, datetime.datetime(2020, 6, 1, 0, 0): 7623.0, datetime.datetime(2020, 7, 1, 0, 0): 14856.0, datetime.datetime(2020, 8, 1, 0, 0): 15065.0, datetime.datetime(2020, 9, 1, 0, 0): 9343.0, datetime.datetime(2020, 10, 1, 0, 0): 11605.0, datetime.datetime(2020, 12, 1, 0, 0): 47113.0, datetime.datetime(2021, 1, 1, 0, 0): 84139.0, datetime.datetime(2021, 2, 1, 0, 0): 23957.0, datetime.datetime(2021, 3, 1, 0, 0): 7771.0, datetime.datetime(2021, 4, 1, 0, 0): 63.0}
# Alabama {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 10.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): nan, datetime.datetime(2020, 3, 29, 0, 0): 11.0, datetime.datetime(2020, 4, 5, 0, 0): 27.0, datetime.datetime(2020, 4, 12, 0, 0): 26.0, datetime.datetime(2020, 4, 19, 0, 0): 19.0, datetime.datetime(2020, 4, 26, 0, 0): 26.0, datetime.datetime(2020, 5, 3, 0, 0): 34.0, datetime.datetime(2020, 5, 10, 0, 0): 30.0, datetime.datetime(2020, 5, 17, 0, 0): 23.0, datetime.datetime(2020, 5, 24, 0, 0): 30.0, datetime.datetime(2020, 5, 31, 0, 0): 32.0, datetime.datetime(2020, 6, 7, 0, 0): 29.0, datetime.datetime(2020, 6, 14, 0, 0): 25.0, datetime.datetime(2020, 6, 21, 0, 0): 30.0, datetime.datetime(2020, 6, 28, 0, 0): 48.0, datetime.datetime(2020, 7, 5, 0, 0): 36.0, datetime.datetime(2020, 7, 12, 0, 0): 45.0, datetime.datetime(2020, 7, 19, 0, 0): 89.0, datetime.datetime(2020, 7, 26, 0, 0): 95.0, datetime.datetime(2020, 8, 2, 0, 0): 87.0, datetime.datetime(2020, 8, 9, 0, 0): 83.0, datetime.datetime(2020, 8, 16, 0, 0): 64.0, datetime.datetime(2020, 8, 23, 0, 0): 71.0, datetime.datetime(2020, 8, 30, 0, 0): 58.0, datetime.datetime(2020, 9, 6, 0, 0): 50.0, datetime.datetime(2020, 9, 13, 0, 0): 46.0, datetime.datetime(2020, 9, 20, 0, 0): 31.0, datetime.datetime(2020, 9, 27, 0, 0): 36.0, datetime.datetime(2020, 10, 4, 0, 0): 50.0, datetime.datetime(2020, 10, 11, 0, 0): 41.0, datetime.datetime(2020, 10, 18, 0, 0): 35.0, datetime.datetime(2020, 10, 25, 0, 0): 47.0, datetime.datetime(2020, 11, 1, 0, 0): 230.0, datetime.datetime(2020, 11, 8, 0, 0): 61.0, datetime.datetime(2020, 11, 15, 0, 0): 44.0, datetime.datetime(2020, 11, 22, 0, 0): 56.0, datetime.datetime(2020, 11, 29, 0, 0): 71.0, datetime.datetime(2020, 12, 6, 0, 0): 130.0, datetime.datetime(2020, 12, 13, 0, 0): 143.0, datetime.datetime(2020, 12, 20, 0, 0): 137.0, datetime.datetime(2020, 12, 27, 0, 0): 180.0, datetime.datetime(2021, 1, 3, 0, 0): 183.0, datetime.datetime(2021, 1, 10, 0, 0): 236.0, datetime.datetime(2021, 1, 17, 0, 0): 199.0, datetime.datetime(2021, 1, 24, 0, 0): 174.0, datetime.datetime(2021, 1, 31, 0, 0): 119.0, datetime.datetime(2021, 2, 7, 0, 0): 100.0, datetime.datetime(2021, 2, 14, 0, 0): 64.0, datetime.datetime(2021, 2, 21, 0, 0): 57.0, datetime.datetime(2021, 2, 28, 0, 0): 32.0, datetime.datetime(2021, 3, 7, 0, 0): 28.0, datetime.datetime(2021, 3, 14, 0, 0): 20.0, datetime.datetime(2021, 3, 21, 0, 0): 11.0, datetime.datetime(2021, 3, 28, 0, 0): nan, datetime.datetime(2020, 1, 1, 0, 0): 3458.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 96.0, datetime.datetime(2020, 5, 1, 0, 0): 131.0, datetime.datetime(2020, 6, 1, 0, 0): 128.0, datetime.datetime(2020, 7, 1, 0, 0): 279.0, datetime.datetime(2020, 8, 1, 0, 0): 334.0, datetime.datetime(2020, 9, 1, 0, 0): 193.0, datetime.datetime(2020, 10, 1, 0, 0): 189.0, datetime.datetime(2020, 12, 1, 0, 0): 579.0, datetime.datetime(2021, 1, 1, 0, 0): 1289.0, datetime.datetime(2021, 2, 1, 0, 0): 328.0, datetime.datetime(2021, 3, 1, 0, 0): 90.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Alaska {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): nan, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): 0.0, datetime.datetime(2020, 3, 22, 0, 0): nan, datetime.datetime(2020, 3, 29, 0, 0): nan, datetime.datetime(2020, 4, 5, 0, 0): nan, datetime.datetime(2020, 4, 12, 0, 0): 0.0, datetime.datetime(2020, 4, 19, 0, 0): 0.0, datetime.datetime(2020, 4, 26, 0, 0): 0.0, datetime.datetime(2020, 5, 3, 0, 0): 0.0, datetime.datetime(2020, 5, 10, 0, 0): 0.0, datetime.datetime(2020, 5, 17, 0, 0): 0.0, datetime.datetime(2020, 5, 24, 0, 0): 0.0, datetime.datetime(2020, 5, 31, 0, 0): 0.0, datetime.datetime(2020, 6, 7, 0, 0): nan, datetime.datetime(2020, 6, 14, 0, 0): 0.0, datetime.datetime(2020, 6, 21, 0, 0): 0.0, datetime.datetime(2020, 6, 28, 0, 0): 0.0, datetime.datetime(2020, 7, 5, 0, 0): nan, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): nan, datetime.datetime(2020, 7, 26, 0, 0): nan, datetime.datetime(2020, 8, 2, 0, 0): nan, datetime.datetime(2020, 8, 9, 0, 0): nan, datetime.datetime(2020, 8, 16, 0, 0): nan, datetime.datetime(2020, 8, 23, 0, 0): nan, datetime.datetime(2020, 8, 30, 0, 0): nan, datetime.datetime(2020, 9, 6, 0, 0): nan, datetime.datetime(2020, 9, 13, 0, 0): 0.0, datetime.datetime(2020, 9, 20, 0, 0): nan, datetime.datetime(2020, 9, 27, 0, 0): 0.0, datetime.datetime(2020, 10, 4, 0, 0): nan, datetime.datetime(2020, 10, 11, 0, 0): nan, datetime.datetime(2020, 10, 18, 0, 0): nan, datetime.datetime(2020, 10, 25, 0, 0): nan, datetime.datetime(2020, 11, 1, 0, 0): 44.0, datetime.datetime(2020, 11, 8, 0, 0): 13.0, datetime.datetime(2020, 11, 15, 0, 0): nan, datetime.datetime(2020, 11, 22, 0, 0): 14.0, datetime.datetime(2020, 11, 29, 0, 0): 18.0, datetime.datetime(2020, 12, 6, 0, 0): 12.0, datetime.datetime(2020, 12, 13, 0, 0): 12.0, datetime.datetime(2020, 12, 20, 0, 0): 11.0, datetime.datetime(2020, 12, 27, 0, 0): nan, datetime.datetime(2021, 1, 3, 0, 0): nan, datetime.datetime(2021, 1, 10, 0, 0): nan, datetime.datetime(2021, 1, 17, 0, 0): nan, datetime.datetime(2021, 1, 24, 0, 0): nan, datetime.datetime(2021, 1, 31, 0, 0): nan, datetime.datetime(2021, 2, 7, 0, 0): nan, datetime.datetime(2021, 2, 14, 0, 0): nan, datetime.datetime(2021, 2, 21, 0, 0): nan, datetime.datetime(2021, 2, 28, 0, 0): 0.0, datetime.datetime(2021, 3, 7, 0, 0): nan, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): 0.0, datetime.datetime(2021, 3, 28, 0, 0): 0.0, datetime.datetime(2020, 1, 1, 0, 0): 165.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): nan, datetime.datetime(2020, 5, 1, 0, 0): 0.0, datetime.datetime(2020, 6, 1, 0, 0): nan, datetime.datetime(2020, 7, 1, 0, 0): nan, datetime.datetime(2020, 8, 1, 0, 0): nan, datetime.datetime(2020, 9, 1, 0, 0): nan, datetime.datetime(2020, 10, 1, 0, 0): 16.0, datetime.datetime(2020, 12, 1, 0, 0): 51.0, datetime.datetime(2021, 1, 1, 0, 0): 26.0, datetime.datetime(2021, 2, 1, 0, 0): nan, datetime.datetime(2021, 3, 1, 0, 0): nan, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Arizona {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 33.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): 19.0, datetime.datetime(2020, 3, 29, 0, 0): 32.0, datetime.datetime(2020, 4, 5, 0, 0): 52.0, datetime.datetime(2020, 4, 12, 0, 0): 43.0, datetime.datetime(2020, 4, 19, 0, 0): 42.0, datetime.datetime(2020, 4, 26, 0, 0): 46.0, datetime.datetime(2020, 5, 3, 0, 0): 71.0, datetime.datetime(2020, 5, 10, 0, 0): 69.0, datetime.datetime(2020, 5, 17, 0, 0): 52.0, datetime.datetime(2020, 5, 24, 0, 0): 51.0, datetime.datetime(2020, 5, 31, 0, 0): 72.0, datetime.datetime(2020, 6, 7, 0, 0): 99.0, datetime.datetime(2020, 6, 14, 0, 0): 108.0, datetime.datetime(2020, 6, 21, 0, 0): 137.0, datetime.datetime(2020, 6, 28, 0, 0): 212.0, datetime.datetime(2020, 7, 5, 0, 0): 311.0, datetime.datetime(2020, 7, 12, 0, 0): 339.0, datetime.datetime(2020, 7, 19, 0, 0): 283.0, datetime.datetime(2020, 7, 26, 0, 0): 220.0, datetime.datetime(2020, 8, 2, 0, 0): 181.0, datetime.datetime(2020, 8, 9, 0, 0): 145.0, datetime.datetime(2020, 8, 16, 0, 0): 92.0, datetime.datetime(2020, 8, 23, 0, 0): 72.0, datetime.datetime(2020, 8, 30, 0, 0): 60.0, datetime.datetime(2020, 9, 6, 0, 0): 36.0, datetime.datetime(2020, 9, 13, 0, 0): 29.0, datetime.datetime(2020, 9, 20, 0, 0): 27.0, datetime.datetime(2020, 9, 27, 0, 0): 18.0, datetime.datetime(2020, 10, 4, 0, 0): 28.0, datetime.datetime(2020, 10, 11, 0, 0): 27.0, datetime.datetime(2020, 10, 18, 0, 0): 35.0, datetime.datetime(2020, 10, 25, 0, 0): 39.0, datetime.datetime(2020, 11, 1, 0, 0): 476.0, datetime.datetime(2020, 11, 8, 0, 0): 64.0, datetime.datetime(2020, 11, 15, 0, 0): 110.0, datetime.datetime(2020, 11, 22, 0, 0): 183.0, datetime.datetime(2020, 11, 29, 0, 0): 255.0, datetime.datetime(2020, 12, 6, 0, 0): 353.0, datetime.datetime(2020, 12, 13, 0, 0): 456.0, datetime.datetime(2020, 12, 20, 0, 0): 498.0, datetime.datetime(2020, 12, 27, 0, 0): 542.0, datetime.datetime(2021, 1, 3, 0, 0): 575.0, datetime.datetime(2021, 1, 10, 0, 0): 593.0, datetime.datetime(2021, 1, 17, 0, 0): 565.0, datetime.datetime(2021, 1, 24, 0, 0): 461.0, datetime.datetime(2021, 1, 31, 0, 0): 370.0, datetime.datetime(2021, 2, 7, 0, 0): 299.0, datetime.datetime(2021, 2, 14, 0, 0): 210.0, datetime.datetime(2021, 2, 21, 0, 0): 146.0, datetime.datetime(2021, 2, 28, 0, 0): 100.0, datetime.datetime(2021, 3, 7, 0, 0): 63.0, datetime.datetime(2021, 3, 14, 0, 0): 41.0, datetime.datetime(2021, 3, 21, 0, 0): 22.0, datetime.datetime(2021, 3, 28, 0, 0): nan, datetime.datetime(2020, 1, 1, 0, 0): 9021.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 191.0, datetime.datetime(2020, 5, 1, 0, 0): 267.0, datetime.datetime(2020, 6, 1, 0, 0): 488.0, datetime.datetime(2020, 7, 1, 0, 0): 1249.0, datetime.datetime(2020, 8, 1, 0, 0): 539.0, datetime.datetime(2020, 9, 1, 0, 0): 149.0, datetime.datetime(2020, 10, 1, 0, 0): 134.0, datetime.datetime(2020, 12, 1, 0, 0): 1907.0, datetime.datetime(2021, 1, 1, 0, 0): 3588.0, datetime.datetime(2021, 2, 1, 0, 0): 984.0, datetime.datetime(2021, 3, 1, 0, 0): 213.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Arkansas {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): nan, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): 0.0, datetime.datetime(2020, 3, 22, 0, 0): nan, datetime.datetime(2020, 3, 29, 0, 0): nan, datetime.datetime(2020, 4, 5, 0, 0): nan, datetime.datetime(2020, 4, 12, 0, 0): nan, datetime.datetime(2020, 4, 19, 0, 0): nan, datetime.datetime(2020, 4, 26, 0, 0): nan, datetime.datetime(2020, 5, 3, 0, 0): nan, datetime.datetime(2020, 5, 10, 0, 0): nan, datetime.datetime(2020, 5, 17, 0, 0): nan, datetime.datetime(2020, 5, 24, 0, 0): 12.0, datetime.datetime(2020, 5, 31, 0, 0): 12.0, datetime.datetime(2020, 6, 7, 0, 0): 17.0, datetime.datetime(2020, 6, 14, 0, 0): 16.0, datetime.datetime(2020, 6, 21, 0, 0): 21.0, datetime.datetime(2020, 6, 28, 0, 0): 17.0, datetime.datetime(2020, 7, 5, 0, 0): 23.0, datetime.datetime(2020, 7, 12, 0, 0): 25.0, datetime.datetime(2020, 7, 19, 0, 0): 36.0, datetime.datetime(2020, 7, 26, 0, 0): 44.0, datetime.datetime(2020, 8, 2, 0, 0): 42.0, datetime.datetime(2020, 8, 9, 0, 0): 33.0, datetime.datetime(2020, 8, 16, 0, 0): 49.0, datetime.datetime(2020, 8, 23, 0, 0): 42.0, datetime.datetime(2020, 8, 30, 0, 0): 42.0, datetime.datetime(2020, 9, 6, 0, 0): 49.0, datetime.datetime(2020, 9, 13, 0, 0): 35.0, datetime.datetime(2020, 9, 20, 0, 0): 47.0, datetime.datetime(2020, 9, 27, 0, 0): 56.0, datetime.datetime(2020, 10, 4, 0, 0): 81.0, datetime.datetime(2020, 10, 11, 0, 0): 68.0, datetime.datetime(2020, 10, 18, 0, 0): 79.0, datetime.datetime(2020, 10, 25, 0, 0): 65.0, datetime.datetime(2020, 11, 1, 0, 0): 340.0, datetime.datetime(2020, 11, 8, 0, 0): 77.0, datetime.datetime(2020, 11, 15, 0, 0): 73.0, datetime.datetime(2020, 11, 22, 0, 0): 100.0, datetime.datetime(2020, 11, 29, 0, 0): 115.0, datetime.datetime(2020, 12, 6, 0, 0): 93.0, datetime.datetime(2020, 12, 13, 0, 0): 123.0, datetime.datetime(2020, 12, 20, 0, 0): 111.0, datetime.datetime(2020, 12, 27, 0, 0): 148.0, datetime.datetime(2021, 1, 3, 0, 0): 129.0, datetime.datetime(2021, 1, 10, 0, 0): 149.0, datetime.datetime(2021, 1, 17, 0, 0): 149.0, datetime.datetime(2021, 1, 24, 0, 0): 115.0, datetime.datetime(2021, 1, 31, 0, 0): 96.0, datetime.datetime(2021, 2, 7, 0, 0): 71.0, datetime.datetime(2021, 2, 14, 0, 0): 43.0, datetime.datetime(2021, 2, 21, 0, 0): 48.0, datetime.datetime(2021, 2, 28, 0, 0): 36.0, datetime.datetime(2021, 3, 7, 0, 0): 23.0, datetime.datetime(2021, 3, 14, 0, 0): 14.0, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): nan, datetime.datetime(2020, 1, 1, 0, 0): 2732.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 16.0, datetime.datetime(2020, 5, 1, 0, 0): 30.0, datetime.datetime(2020, 6, 1, 0, 0): 75.0, datetime.datetime(2020, 7, 1, 0, 0): 129.0, datetime.datetime(2020, 8, 1, 0, 0): 181.0, datetime.datetime(2020, 9, 1, 0, 0): 199.0, datetime.datetime(2020, 10, 1, 0, 0): 315.0, datetime.datetime(2020, 12, 1, 0, 0): 520.0, datetime.datetime(2021, 1, 1, 0, 0): 924.0, datetime.datetime(2021, 2, 1, 0, 0): 250.0, datetime.datetime(2021, 3, 1, 0, 0): 83.0, datetime.datetime(2021, 4, 1, 0, 0): nan}
# California {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): nan, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 147.0, datetime.datetime(2020, 3, 8, 0, 0): nan, datetime.datetime(2020, 3, 15, 0, 0): 19.0, datetime.datetime(2020, 3, 22, 0, 0): 70.0, datetime.datetime(2020, 3, 29, 0, 0): 158.0, datetime.datetime(2020, 4, 5, 0, 0): 222.0, datetime.datetime(2020, 4, 12, 0, 0): 325.0, datetime.datetime(2020, 4, 19, 0, 0): 295.0, datetime.datetime(2020, 4, 26, 0, 0): 294.0, datetime.datetime(2020, 5, 3, 0, 0): 298.0, datetime.datetime(2020, 5, 10, 0, 0): 273.0, datetime.datetime(2020, 5, 17, 0, 0): 268.0, datetime.datetime(2020, 5, 24, 0, 0): 262.0, datetime.datetime(2020, 5, 31, 0, 0): 252.0, datetime.datetime(2020, 6, 7, 0, 0): 242.0, datetime.datetime(2020, 6, 14, 0, 0): 227.0, datetime.datetime(2020, 6, 21, 0, 0): 263.0, datetime.datetime(2020, 6, 28, 0, 0): 345.0, datetime.datetime(2020, 7, 5, 0, 0): 396.0, datetime.datetime(2020, 7, 12, 0, 0): 477.0, datetime.datetime(2020, 7, 19, 0, 0): 561.0, datetime.datetime(2020, 7, 26, 0, 0): 572.0, datetime.datetime(2020, 8, 2, 0, 0): 578.0, datetime.datetime(2020, 8, 9, 0, 0): 504.0, datetime.datetime(2020, 8, 16, 0, 0): 468.0, datetime.datetime(2020, 8, 23, 0, 0): 405.0, datetime.datetime(2020, 8, 30, 0, 0): 353.0, datetime.datetime(2020, 9, 6, 0, 0): 294.0, datetime.datetime(2020, 9, 13, 0, 0): 269.0, datetime.datetime(2020, 9, 20, 0, 0): 265.0, datetime.datetime(2020, 9, 27, 0, 0): 195.0, datetime.datetime(2020, 10, 4, 0, 0): 223.0, datetime.datetime(2020, 10, 11, 0, 0): 163.0, datetime.datetime(2020, 10, 18, 0, 0): 168.0, datetime.datetime(2020, 10, 25, 0, 0): 171.0, datetime.datetime(2020, 11, 1, 0, 0): 1378.0, datetime.datetime(2020, 11, 8, 0, 0): 215.0, datetime.datetime(2020, 11, 15, 0, 0): 348.0, datetime.datetime(2020, 11, 22, 0, 0): 451.0, datetime.datetime(2020, 11, 29, 0, 0): 728.0, datetime.datetime(2020, 12, 6, 0, 0): 1090.0, datetime.datetime(2020, 12, 13, 0, 0): 1695.0, datetime.datetime(2020, 12, 20, 0, 0): 2183.0, datetime.datetime(2020, 12, 27, 0, 0): 2730.0, datetime.datetime(2021, 1, 3, 0, 0): 3084.0, datetime.datetime(2021, 1, 10, 0, 0): 2986.0, datetime.datetime(2021, 1, 17, 0, 0): 2590.0, datetime.datetime(2021, 1, 24, 0, 0): 2148.0, datetime.datetime(2021, 1, 31, 0, 0): 1735.0, datetime.datetime(2021, 2, 7, 0, 0): 1338.0, datetime.datetime(2021, 2, 14, 0, 0): 981.0, datetime.datetime(2021, 2, 21, 0, 0): 653.0, datetime.datetime(2021, 2, 28, 0, 0): 454.0, datetime.datetime(2021, 3, 7, 0, 0): 243.0, datetime.datetime(2021, 3, 14, 0, 0): 178.0, datetime.datetime(2021, 3, 21, 0, 0): 80.0, datetime.datetime(2021, 3, 28, 0, 0): 22.0, datetime.datetime(2020, 1, 1, 0, 0): 36011.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 1152.0, datetime.datetime(2020, 5, 1, 0, 0): 1221.0, datetime.datetime(2020, 6, 1, 0, 0): 1095.0, datetime.datetime(2020, 7, 1, 0, 0): 2132.0, datetime.datetime(2020, 8, 1, 0, 0): 2144.0, datetime.datetime(2020, 9, 1, 0, 0): 1172.0, datetime.datetime(2020, 10, 1, 0, 0): 814.0, datetime.datetime(2020, 12, 1, 0, 0): 7420.0, datetime.datetime(2021, 1, 1, 0, 0): 17335.0, datetime.datetime(2021, 2, 1, 0, 0): 4514.0, datetime.datetime(2021, 3, 1, 0, 0): 897.0, datetime.datetime(2021, 4, 1, 0, 0): nan}
# Colorado {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 60.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): 27.0, datetime.datetime(2020, 3, 29, 0, 0): 86.0, datetime.datetime(2020, 4, 5, 0, 0): 123.0, datetime.datetime(2020, 4, 12, 0, 0): 118.0, datetime.datetime(2020, 4, 19, 0, 0): 111.0, datetime.datetime(2020, 4, 26, 0, 0): 90.0, datetime.datetime(2020, 5, 3, 0, 0): 65.0, datetime.datetime(2020, 5, 10, 0, 0): 45.0, datetime.datetime(2020, 5, 17, 0, 0): 28.0, datetime.datetime(2020, 5, 24, 0, 0): 39.0, datetime.datetime(2020, 5, 31, 0, 0): 32.0, datetime.datetime(2020, 6, 7, 0, 0): 34.0, datetime.datetime(2020, 6, 14, 0, 0): 19.0, datetime.datetime(2020, 6, 21, 0, 0): nan, datetime.datetime(2020, 6, 28, 0, 0): 14.0, datetime.datetime(2020, 7, 5, 0, 0): 11.0, datetime.datetime(2020, 7, 12, 0, 0): 22.0, datetime.datetime(2020, 7, 19, 0, 0): 24.0, datetime.datetime(2020, 7, 26, 0, 0): 18.0, datetime.datetime(2020, 8, 2, 0, 0): 20.0, datetime.datetime(2020, 8, 9, 0, 0): 18.0, datetime.datetime(2020, 8, 16, 0, 0): 12.0, datetime.datetime(2020, 8, 23, 0, 0): nan, datetime.datetime(2020, 8, 30, 0, 0): nan, datetime.datetime(2020, 9, 6, 0, 0): 13.0, datetime.datetime(2020, 9, 13, 0, 0): nan, datetime.datetime(2020, 9, 20, 0, 0): 10.0, datetime.datetime(2020, 9, 27, 0, 0): 13.0, datetime.datetime(2020, 10, 4, 0, 0): 17.0, datetime.datetime(2020, 10, 11, 0, 0): 22.0, datetime.datetime(2020, 10, 18, 0, 0): 29.0, datetime.datetime(2020, 10, 25, 0, 0): 43.0, datetime.datetime(2020, 11, 1, 0, 0): 515.0, datetime.datetime(2020, 11, 8, 0, 0): 114.0, datetime.datetime(2020, 11, 15, 0, 0): 112.0, datetime.datetime(2020, 11, 22, 0, 0): 163.0, datetime.datetime(2020, 11, 29, 0, 0): 230.0, datetime.datetime(2020, 12, 6, 0, 0): 211.0, datetime.datetime(2020, 12, 13, 0, 0): 195.0, datetime.datetime(2020, 12, 20, 0, 0): 149.0, datetime.datetime(2020, 12, 27, 0, 0): 141.0, datetime.datetime(2021, 1, 3, 0, 0): 100.0, datetime.datetime(2021, 1, 10, 0, 0): 78.0, datetime.datetime(2021, 1, 17, 0, 0): 80.0, datetime.datetime(2021, 1, 24, 0, 0): 64.0, datetime.datetime(2021, 1, 31, 0, 0): 62.0, datetime.datetime(2021, 2, 7, 0, 0): 52.0, datetime.datetime(2021, 2, 14, 0, 0): 36.0, datetime.datetime(2021, 2, 21, 0, 0): 32.0, datetime.datetime(2021, 2, 28, 0, 0): 20.0, datetime.datetime(2021, 3, 7, 0, 0): 20.0, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): nan, datetime.datetime(2020, 1, 1, 0, 0): 3093.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 474.0, datetime.datetime(2020, 5, 1, 0, 0): 212.0, datetime.datetime(2020, 6, 1, 0, 0): 93.0, datetime.datetime(2020, 7, 1, 0, 0): 85.0, datetime.datetime(2020, 8, 1, 0, 0): 59.0, datetime.datetime(2020, 9, 1, 0, 0): 46.0, datetime.datetime(2020, 10, 1, 0, 0): 116.0, datetime.datetime(2020, 12, 1, 0, 0): 840.0, datetime.datetime(2021, 1, 1, 0, 0): 593.0, datetime.datetime(2021, 2, 1, 0, 0): 175.0, datetime.datetime(2021, 3, 1, 0, 0): 52.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Connecticut {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 30.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): 13.0, datetime.datetime(2020, 3, 29, 0, 0): 34.0, datetime.datetime(2020, 4, 5, 0, 0): 120.0, datetime.datetime(2020, 4, 12, 0, 0): 127.0, datetime.datetime(2020, 4, 19, 0, 0): 147.0, datetime.datetime(2020, 4, 26, 0, 0): 131.0, datetime.datetime(2020, 5, 3, 0, 0): 118.0, datetime.datetime(2020, 5, 10, 0, 0): 86.0, datetime.datetime(2020, 5, 17, 0, 0): 58.0, datetime.datetime(2020, 5, 24, 0, 0): 44.0, datetime.datetime(2020, 5, 31, 0, 0): 19.0, datetime.datetime(2020, 6, 7, 0, 0): 17.0, datetime.datetime(2020, 6, 14, 0, 0): nan, datetime.datetime(2020, 6, 21, 0, 0): 16.0, datetime.datetime(2020, 6, 28, 0, 0): nan, datetime.datetime(2020, 7, 5, 0, 0): nan, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): nan, datetime.datetime(2020, 7, 26, 0, 0): nan, datetime.datetime(2020, 8, 2, 0, 0): 0.0, datetime.datetime(2020, 8, 9, 0, 0): nan, datetime.datetime(2020, 8, 16, 0, 0): nan, datetime.datetime(2020, 8, 23, 0, 0): nan, datetime.datetime(2020, 8, 30, 0, 0): nan, datetime.datetime(2020, 9, 6, 0, 0): nan, datetime.datetime(2020, 9, 13, 0, 0): nan, datetime.datetime(2020, 9, 20, 0, 0): 0.0, datetime.datetime(2020, 9, 27, 0, 0): nan, datetime.datetime(2020, 10, 4, 0, 0): nan, datetime.datetime(2020, 10, 11, 0, 0): nan, datetime.datetime(2020, 10, 18, 0, 0): nan, datetime.datetime(2020, 10, 25, 0, 0): 22.0, datetime.datetime(2020, 11, 1, 0, 0): 175.0, datetime.datetime(2020, 11, 8, 0, 0): 28.0, datetime.datetime(2020, 11, 15, 0, 0): 51.0, datetime.datetime(2020, 11, 22, 0, 0): 56.0, datetime.datetime(2020, 11, 29, 0, 0): 83.0, datetime.datetime(2020, 12, 6, 0, 0): 72.0, datetime.datetime(2020, 12, 13, 0, 0): 89.0, datetime.datetime(2020, 12, 20, 0, 0): 83.0, datetime.datetime(2020, 12, 27, 0, 0): 116.0, datetime.datetime(2021, 1, 3, 0, 0): 98.0, datetime.datetime(2021, 1, 10, 0, 0): 92.0, datetime.datetime(2021, 1, 17, 0, 0): 80.0, datetime.datetime(2021, 1, 24, 0, 0): 68.0, datetime.datetime(2021, 1, 31, 0, 0): 73.0, datetime.datetime(2021, 2, 7, 0, 0): 59.0, datetime.datetime(2021, 2, 14, 0, 0): 30.0, datetime.datetime(2021, 2, 21, 0, 0): 30.0, datetime.datetime(2021, 2, 28, 0, 0): 20.0, datetime.datetime(2021, 3, 7, 0, 0): 17.0, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): 0.0, datetime.datetime(2021, 3, 28, 0, 0): 0.0, datetime.datetime(2020, 1, 1, 0, 0): 2190.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 505.0, datetime.datetime(2020, 5, 1, 0, 0): 350.0, datetime.datetime(2020, 6, 1, 0, 0): 57.0, datetime.datetime(2020, 7, 1, 0, 0): 12.0, datetime.datetime(2020, 8, 1, 0, 0): nan, datetime.datetime(2020, 9, 1, 0, 0): 11.0, datetime.datetime(2020, 10, 1, 0, 0): 40.0, datetime.datetime(2020, 12, 1, 0, 0): 393.0, datetime.datetime(2021, 1, 1, 0, 0): 609.0, datetime.datetime(2021, 2, 1, 0, 0): 181.0, datetime.datetime(2021, 3, 1, 0, 0): 45.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Delaware {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): nan, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): 0.0, datetime.datetime(2020, 3, 22, 0, 0): nan, datetime.datetime(2020, 3, 29, 0, 0): nan, datetime.datetime(2020, 4, 5, 0, 0): 11.0, datetime.datetime(2020, 4, 12, 0, 0): 18.0, datetime.datetime(2020, 4, 19, 0, 0): 27.0, datetime.datetime(2020, 4, 26, 0, 0): 29.0, datetime.datetime(2020, 5, 3, 0, 0): 28.0, datetime.datetime(2020, 5, 10, 0, 0): 19.0, datetime.datetime(2020, 5, 17, 0, 0): 17.0, datetime.datetime(2020, 5, 24, 0, 0): 16.0, datetime.datetime(2020, 5, 31, 0, 0): nan, datetime.datetime(2020, 6, 7, 0, 0): nan, datetime.datetime(2020, 6, 14, 0, 0): nan, datetime.datetime(2020, 6, 21, 0, 0): nan, datetime.datetime(2020, 6, 28, 0, 0): nan, datetime.datetime(2020, 7, 5, 0, 0): nan, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): nan, datetime.datetime(2020, 7, 26, 0, 0): nan, datetime.datetime(2020, 8, 2, 0, 0): nan, datetime.datetime(2020, 8, 9, 0, 0): nan, datetime.datetime(2020, 8, 16, 0, 0): nan, datetime.datetime(2020, 8, 23, 0, 0): 0.0, datetime.datetime(2020, 8, 30, 0, 0): nan, datetime.datetime(2020, 9, 6, 0, 0): nan, datetime.datetime(2020, 9, 13, 0, 0): nan, datetime.datetime(2020, 9, 20, 0, 0): nan, datetime.datetime(2020, 9, 27, 0, 0): nan, datetime.datetime(2020, 10, 4, 0, 0): nan, datetime.datetime(2020, 10, 11, 0, 0): nan, datetime.datetime(2020, 10, 18, 0, 0): nan, datetime.datetime(2020, 10, 25, 0, 0): 12.0, datetime.datetime(2020, 11, 1, 0, 0): 49.0, datetime.datetime(2020, 11, 8, 0, 0): 10.0, datetime.datetime(2020, 11, 15, 0, 0): nan, datetime.datetime(2020, 11, 22, 0, 0): 18.0, datetime.datetime(2020, 11, 29, 0, 0): 19.0, datetime.datetime(2020, 12, 6, 0, 0): 22.0, datetime.datetime(2020, 12, 13, 0, 0): 26.0, datetime.datetime(2020, 12, 20, 0, 0): 28.0, datetime.datetime(2020, 12, 27, 0, 0): 27.0, datetime.datetime(2021, 1, 3, 0, 0): 32.0, datetime.datetime(2021, 1, 10, 0, 0): 39.0, datetime.datetime(2021, 1, 17, 0, 0): 41.0, datetime.datetime(2021, 1, 24, 0, 0): 34.0, datetime.datetime(2021, 1, 31, 0, 0): 17.0, datetime.datetime(2021, 2, 7, 0, 0): 16.0, datetime.datetime(2021, 2, 14, 0, 0): nan, datetime.datetime(2021, 2, 21, 0, 0): nan, datetime.datetime(2021, 2, 28, 0, 0): nan, datetime.datetime(2021, 3, 7, 0, 0): nan, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): 0.0, datetime.datetime(2020, 1, 1, 0, 0): 642.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 78.0, datetime.datetime(2020, 5, 1, 0, 0): 90.0, datetime.datetime(2020, 6, 1, 0, 0): 27.0, datetime.datetime(2020, 7, 1, 0, 0): 14.0, datetime.datetime(2020, 8, 1, 0, 0): nan, datetime.datetime(2020, 9, 1, 0, 0): 11.0, datetime.datetime(2020, 10, 1, 0, 0): 35.0, datetime.datetime(2020, 12, 1, 0, 0): 114.0, datetime.datetime(2021, 1, 1, 0, 0): 214.0, datetime.datetime(2021, 2, 1, 0, 0): 48.0, datetime.datetime(2021, 3, 1, 0, 0): 14.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# District of Columbia {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 15.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): nan, datetime.datetime(2020, 3, 29, 0, 0): 25.0, datetime.datetime(2020, 4, 5, 0, 0): 37.0, datetime.datetime(2020, 4, 12, 0, 0): 57.0, datetime.datetime(2020, 4, 19, 0, 0): 90.0, datetime.datetime(2020, 4, 26, 0, 0): 75.0, datetime.datetime(2020, 5, 3, 0, 0): 86.0, datetime.datetime(2020, 5, 10, 0, 0): 71.0, datetime.datetime(2020, 5, 17, 0, 0): 46.0, datetime.datetime(2020, 5, 24, 0, 0): 41.0, datetime.datetime(2020, 5, 31, 0, 0): 36.0, datetime.datetime(2020, 6, 7, 0, 0): 30.0, datetime.datetime(2020, 6, 14, 0, 0): 21.0, datetime.datetime(2020, 6, 21, 0, 0): 18.0, datetime.datetime(2020, 6, 28, 0, 0): 13.0, datetime.datetime(2020, 7, 5, 0, 0): nan, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): nan, datetime.datetime(2020, 7, 26, 0, 0): nan, datetime.datetime(2020, 8, 2, 0, 0): nan, datetime.datetime(2020, 8, 9, 0, 0): nan, datetime.datetime(2020, 8, 16, 0, 0): 10.0, datetime.datetime(2020, 8, 23, 0, 0): nan, datetime.datetime(2020, 8, 30, 0, 0): nan, datetime.datetime(2020, 9, 6, 0, 0): nan, datetime.datetime(2020, 9, 13, 0, 0): nan, datetime.datetime(2020, 9, 20, 0, 0): nan, datetime.datetime(2020, 9, 27, 0, 0): nan, datetime.datetime(2020, 10, 4, 0, 0): 13.0, datetime.datetime(2020, 10, 11, 0, 0): nan, datetime.datetime(2020, 10, 18, 0, 0): nan, datetime.datetime(2020, 10, 25, 0, 0): nan, datetime.datetime(2020, 11, 1, 0, 0): 48.0, datetime.datetime(2020, 11, 8, 0, 0): nan, datetime.datetime(2020, 11, 15, 0, 0): 14.0, datetime.datetime(2020, 11, 22, 0, 0): 12.0, datetime.datetime(2020, 11, 29, 0, 0): 17.0, datetime.datetime(2020, 12, 6, 0, 0): 19.0, datetime.datetime(2020, 12, 13, 0, 0): 29.0, datetime.datetime(2020, 12, 20, 0, 0): 35.0, datetime.datetime(2020, 12, 27, 0, 0): 32.0, datetime.datetime(2021, 1, 3, 0, 0): 25.0, datetime.datetime(2021, 1, 10, 0, 0): 23.0, datetime.datetime(2021, 1, 17, 0, 0): 15.0, datetime.datetime(2021, 1, 24, 0, 0): 36.0, datetime.datetime(2021, 1, 31, 0, 0): 30.0, datetime.datetime(2021, 2, 7, 0, 0): nan, datetime.datetime(2021, 2, 14, 0, 0): 12.0, datetime.datetime(2021, 2, 21, 0, 0): 20.0, datetime.datetime(2021, 2, 28, 0, 0): 10.0, datetime.datetime(2021, 3, 7, 0, 0): nan, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): 0.0, datetime.datetime(2020, 1, 1, 0, 0): 1129.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 260.0, datetime.datetime(2020, 5, 1, 0, 0): 268.0, datetime.datetime(2020, 6, 1, 0, 0): 106.0, datetime.datetime(2020, 7, 1, 0, 0): 30.0, datetime.datetime(2020, 8, 1, 0, 0): 33.0, datetime.datetime(2020, 9, 1, 0, 0): 22.0, datetime.datetime(2020, 10, 1, 0, 0): 33.0, datetime.datetime(2020, 12, 1, 0, 0): 117.0, datetime.datetime(2021, 1, 1, 0, 0): 197.0, datetime.datetime(2021, 2, 1, 0, 0): 65.0, datetime.datetime(2021, 3, 1, 0, 0): 19.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Florida {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 106.0, datetime.datetime(2020, 3, 8, 0, 0): nan, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): 45.0, datetime.datetime(2020, 3, 29, 0, 0): 142.0, datetime.datetime(2020, 4, 5, 0, 0): 159.0, datetime.datetime(2020, 4, 12, 0, 0): 156.0, datetime.datetime(2020, 4, 19, 0, 0): 164.0, datetime.datetime(2020, 4, 26, 0, 0): 170.0, datetime.datetime(2020, 5, 3, 0, 0): 141.0, datetime.datetime(2020, 5, 10, 0, 0): 132.0, datetime.datetime(2020, 5, 17, 0, 0): 117.0, datetime.datetime(2020, 5, 24, 0, 0): 112.0, datetime.datetime(2020, 5, 31, 0, 0): 99.0, datetime.datetime(2020, 6, 7, 0, 0): 101.0, datetime.datetime(2020, 6, 14, 0, 0): 114.0, datetime.datetime(2020, 6, 21, 0, 0): 177.0, datetime.datetime(2020, 6, 28, 0, 0): 226.0, datetime.datetime(2020, 7, 5, 0, 0): 368.0, datetime.datetime(2020, 7, 12, 0, 0): 571.0, datetime.datetime(2020, 7, 19, 0, 0): 730.0, datetime.datetime(2020, 7, 26, 0, 0): 772.0, datetime.datetime(2020, 8, 2, 0, 0): 835.0, datetime.datetime(2020, 8, 9, 0, 0): 680.0, datetime.datetime(2020, 8, 16, 0, 0): 568.0, datetime.datetime(2020, 8, 23, 0, 0): 470.0, datetime.datetime(2020, 8, 30, 0, 0): 388.0, datetime.datetime(2020, 9, 6, 0, 0): 317.0, datetime.datetime(2020, 9, 13, 0, 0): 271.0, datetime.datetime(2020, 9, 20, 0, 0): 247.0, datetime.datetime(2020, 9, 27, 0, 0): 178.0, datetime.datetime(2020, 10, 4, 0, 0): 205.0, datetime.datetime(2020, 10, 11, 0, 0): 196.0, datetime.datetime(2020, 10, 18, 0, 0): 167.0, datetime.datetime(2020, 10, 25, 0, 0): 177.0, datetime.datetime(2020, 11, 1, 0, 0): 1176.0, datetime.datetime(2020, 11, 8, 0, 0): 273.0, datetime.datetime(2020, 11, 15, 0, 0): 271.0, datetime.datetime(2020, 11, 22, 0, 0): 331.0, datetime.datetime(2020, 11, 29, 0, 0): 384.0, datetime.datetime(2020, 12, 6, 0, 0): 395.0, datetime.datetime(2020, 12, 13, 0, 0): 400.0, datetime.datetime(2020, 12, 20, 0, 0): 530.0, datetime.datetime(2020, 12, 27, 0, 0): 645.0, datetime.datetime(2021, 1, 3, 0, 0): 728.0, datetime.datetime(2021, 1, 10, 0, 0): 828.0, datetime.datetime(2021, 1, 17, 0, 0): 793.0, datetime.datetime(2021, 1, 24, 0, 0): 708.0, datetime.datetime(2021, 1, 31, 0, 0): 703.0, datetime.datetime(2021, 2, 7, 0, 0): 584.0, datetime.datetime(2021, 2, 14, 0, 0): 489.0, datetime.datetime(2021, 2, 21, 0, 0): 388.0, datetime.datetime(2021, 2, 28, 0, 0): 326.0, datetime.datetime(2021, 3, 7, 0, 0): 265.0, datetime.datetime(2021, 3, 14, 0, 0): 212.0, datetime.datetime(2021, 3, 21, 0, 0): 134.0, datetime.datetime(2021, 3, 28, 0, 0): 29.0, datetime.datetime(2020, 1, 1, 0, 0): 18826.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 689.0, datetime.datetime(2020, 5, 1, 0, 0): 571.0, datetime.datetime(2020, 6, 1, 0, 0): 547.0, datetime.datetime(2020, 7, 1, 0, 0): 2487.0, datetime.datetime(2020, 8, 1, 0, 0): 2784.0, datetime.datetime(2020, 9, 1, 0, 0): 1193.0, datetime.datetime(2020, 10, 1, 0, 0): 829.0, datetime.datetime(2020, 12, 1, 0, 0): 2075.0, datetime.datetime(2021, 1, 1, 0, 0): 6369.0, datetime.datetime(2021, 2, 1, 0, 0): 2110.0, datetime.datetime(2021, 3, 1, 0, 0): 921.0, datetime.datetime(2021, 4, 1, 0, 0): nan}
# Georgia {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 104.0, datetime.datetime(2020, 3, 8, 0, 0): nan, datetime.datetime(2020, 3, 15, 0, 0): 20.0, datetime.datetime(2020, 3, 22, 0, 0): 44.0, datetime.datetime(2020, 3, 29, 0, 0): 107.0, datetime.datetime(2020, 4, 5, 0, 0): 98.0, datetime.datetime(2020, 4, 12, 0, 0): 112.0, datetime.datetime(2020, 4, 19, 0, 0): 118.0, datetime.datetime(2020, 4, 26, 0, 0): 129.0, datetime.datetime(2020, 5, 3, 0, 0): 92.0, datetime.datetime(2020, 5, 10, 0, 0): 96.0, datetime.datetime(2020, 5, 17, 0, 0): 71.0, datetime.datetime(2020, 5, 24, 0, 0): 47.0, datetime.datetime(2020, 5, 31, 0, 0): 53.0, datetime.datetime(2020, 6, 7, 0, 0): 57.0, datetime.datetime(2020, 6, 14, 0, 0): 32.0, datetime.datetime(2020, 6, 21, 0, 0): 50.0, datetime.datetime(2020, 6, 28, 0, 0): 54.0, datetime.datetime(2020, 7, 5, 0, 0): 97.0, datetime.datetime(2020, 7, 12, 0, 0): 133.0, datetime.datetime(2020, 7, 19, 0, 0): 171.0, datetime.datetime(2020, 7, 26, 0, 0): 187.0, datetime.datetime(2020, 8, 2, 0, 0): 219.0, datetime.datetime(2020, 8, 9, 0, 0): 211.0, datetime.datetime(2020, 8, 16, 0, 0): 211.0, datetime.datetime(2020, 8, 23, 0, 0): 175.0, datetime.datetime(2020, 8, 30, 0, 0): 138.0, datetime.datetime(2020, 9, 6, 0, 0): 135.0, datetime.datetime(2020, 9, 13, 0, 0): 121.0, datetime.datetime(2020, 9, 20, 0, 0): 108.0, datetime.datetime(2020, 9, 27, 0, 0): 82.0, datetime.datetime(2020, 10, 4, 0, 0): 84.0, datetime.datetime(2020, 10, 11, 0, 0): 87.0, datetime.datetime(2020, 10, 18, 0, 0): 82.0, datetime.datetime(2020, 10, 25, 0, 0): 108.0, datetime.datetime(2020, 11, 1, 0, 0): 529.0, datetime.datetime(2020, 11, 8, 0, 0): 123.0, datetime.datetime(2020, 11, 15, 0, 0): 131.0, datetime.datetime(2020, 11, 22, 0, 0): 129.0, datetime.datetime(2020, 11, 29, 0, 0): 151.0, datetime.datetime(2020, 12, 6, 0, 0): 180.0, datetime.datetime(2020, 12, 13, 0, 0): 204.0, datetime.datetime(2020, 12, 20, 0, 0): 270.0, datetime.datetime(2020, 12, 27, 0, 0): 374.0, datetime.datetime(2021, 1, 3, 0, 0): 492.0, datetime.datetime(2021, 1, 10, 0, 0): 538.0, datetime.datetime(2021, 1, 17, 0, 0): 510.0, datetime.datetime(2021, 1, 24, 0, 0): 477.0, datetime.datetime(2021, 1, 31, 0, 0): 382.0, datetime.datetime(2021, 2, 7, 0, 0): 266.0, datetime.datetime(2021, 2, 14, 0, 0): 222.0, datetime.datetime(2021, 2, 21, 0, 0): 155.0, datetime.datetime(2021, 2, 28, 0, 0): 123.0, datetime.datetime(2021, 3, 7, 0, 0): 78.0, datetime.datetime(2021, 3, 14, 0, 0): 54.0, datetime.datetime(2021, 3, 21, 0, 0): 22.0, datetime.datetime(2021, 3, 28, 0, 0): nan, datetime.datetime(2020, 1, 1, 0, 0): 8531.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 485.0, datetime.datetime(2020, 5, 1, 0, 0): 353.0, datetime.datetime(2020, 6, 1, 0, 0): 214.0, datetime.datetime(2020, 7, 1, 0, 0): 591.0, datetime.datetime(2020, 8, 1, 0, 0): 887.0, datetime.datetime(2020, 9, 1, 0, 0): 500.0, datetime.datetime(2020, 10, 1, 0, 0): 398.0, datetime.datetime(2020, 12, 1, 0, 0): 1031.0, datetime.datetime(2021, 1, 1, 0, 0): 3439.0, datetime.datetime(2021, 2, 1, 0, 0): 981.0, datetime.datetime(2021, 3, 1, 0, 0): 265.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Hawaii {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 0.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): 0.0, datetime.datetime(2020, 3, 22, 0, 0): 0.0, datetime.datetime(2020, 3, 29, 0, 0): nan, datetime.datetime(2020, 4, 5, 0, 0): nan, datetime.datetime(2020, 4, 12, 0, 0): 0.0, datetime.datetime(2020, 4, 19, 0, 0): nan, datetime.datetime(2020, 4, 26, 0, 0): nan, datetime.datetime(2020, 5, 3, 0, 0): 0.0, datetime.datetime(2020, 5, 10, 0, 0): 0.0, datetime.datetime(2020, 5, 17, 0, 0): 0.0, datetime.datetime(2020, 5, 24, 0, 0): 0.0, datetime.datetime(2020, 5, 31, 0, 0): 0.0, datetime.datetime(2020, 6, 7, 0, 0): 0.0, datetime.datetime(2020, 6, 14, 0, 0): 0.0, datetime.datetime(2020, 6, 21, 0, 0): 0.0, datetime.datetime(2020, 6, 28, 0, 0): 0.0, datetime.datetime(2020, 7, 5, 0, 0): 0.0, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): 0.0, datetime.datetime(2020, 7, 26, 0, 0): 0.0, datetime.datetime(2020, 8, 2, 0, 0): nan, datetime.datetime(2020, 8, 9, 0, 0): nan, datetime.datetime(2020, 8, 16, 0, 0): nan, datetime.datetime(2020, 8, 23, 0, 0): 19.0, datetime.datetime(2020, 8, 30, 0, 0): 12.0, datetime.datetime(2020, 9, 6, 0, 0): 18.0, datetime.datetime(2020, 9, 13, 0, 0): 11.0, datetime.datetime(2020, 9, 20, 0, 0): 14.0, datetime.datetime(2020, 9, 27, 0, 0): 12.0, datetime.datetime(2020, 10, 4, 0, 0): 10.0, datetime.datetime(2020, 10, 11, 0, 0): nan, datetime.datetime(2020, 10, 18, 0, 0): nan, datetime.datetime(2020, 10, 25, 0, 0): nan, datetime.datetime(2020, 11, 1, 0, 0): 17.0, datetime.datetime(2020, 11, 8, 0, 0): nan, datetime.datetime(2020, 11, 15, 0, 0): nan, datetime.datetime(2020, 11, 22, 0, 0): nan, datetime.datetime(2020, 11, 29, 0, 0): 11.0, datetime.datetime(2020, 12, 6, 0, 0): nan, datetime.datetime(2020, 12, 13, 0, 0): nan, datetime.datetime(2020, 12, 20, 0, 0): nan, datetime.datetime(2020, 12, 27, 0, 0): nan, datetime.datetime(2021, 1, 3, 0, 0): nan, datetime.datetime(2021, 1, 10, 0, 0): nan, datetime.datetime(2021, 1, 17, 0, 0): nan, datetime.datetime(2021, 1, 24, 0, 0): nan, datetime.datetime(2021, 1, 31, 0, 0): nan, datetime.datetime(2021, 2, 7, 0, 0): nan, datetime.datetime(2021, 2, 14, 0, 0): nan, datetime.datetime(2021, 2, 21, 0, 0): nan, datetime.datetime(2021, 2, 28, 0, 0): nan, datetime.datetime(2021, 3, 7, 0, 0): nan, datetime.datetime(2021, 3, 14, 0, 0): 0.0, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): 0.0, datetime.datetime(2020, 1, 1, 0, 0): 225.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): nan, datetime.datetime(2020, 5, 1, 0, 0): 0.0, datetime.datetime(2020, 6, 1, 0, 0): 0.0, datetime.datetime(2020, 7, 1, 0, 0): nan, datetime.datetime(2020, 8, 1, 0, 0): 36.0, datetime.datetime(2020, 9, 1, 0, 0): 60.0, datetime.datetime(2020, 10, 1, 0, 0): 35.0, datetime.datetime(2020, 12, 1, 0, 0): 22.0, datetime.datetime(2021, 1, 1, 0, 0): 48.0, datetime.datetime(2021, 2, 1, 0, 0): 17.0, datetime.datetime(2021, 3, 1, 0, 0): nan, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# ...
# West Virginia {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 0.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): 0.0, datetime.datetime(2020, 3, 22, 0, 0): 0.0, datetime.datetime(2020, 3, 29, 0, 0): 0.0, datetime.datetime(2020, 4, 5, 0, 0): nan, datetime.datetime(2020, 4, 12, 0, 0): nan, datetime.datetime(2020, 4, 19, 0, 0): nan, datetime.datetime(2020, 4, 26, 0, 0): nan, datetime.datetime(2020, 5, 3, 0, 0): 0.0, datetime.datetime(2020, 5, 10, 0, 0): nan, datetime.datetime(2020, 5, 17, 0, 0): nan, datetime.datetime(2020, 5, 24, 0, 0): nan, datetime.datetime(2020, 5, 31, 0, 0): nan, datetime.datetime(2020, 6, 7, 0, 0): nan, datetime.datetime(2020, 6, 14, 0, 0): 0.0, datetime.datetime(2020, 6, 21, 0, 0): nan, datetime.datetime(2020, 6, 28, 0, 0): nan, datetime.datetime(2020, 7, 5, 0, 0): 0.0, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): nan, datetime.datetime(2020, 7, 26, 0, 0): nan, datetime.datetime(2020, 8, 2, 0, 0): nan, datetime.datetime(2020, 8, 9, 0, 0): nan, datetime.datetime(2020, 8, 16, 0, 0): nan, datetime.datetime(2020, 8, 23, 0, 0): 10.0, datetime.datetime(2020, 8, 30, 0, 0): 11.0, datetime.datetime(2020, 9, 6, 0, 0): nan, datetime.datetime(2020, 9, 13, 0, 0): 12.0, datetime.datetime(2020, 9, 20, 0, 0): 11.0, datetime.datetime(2020, 9, 27, 0, 0): nan, datetime.datetime(2020, 10, 4, 0, 0): 20.0, datetime.datetime(2020, 10, 11, 0, 0): 11.0, datetime.datetime(2020, 10, 18, 0, 0): 17.0, datetime.datetime(2020, 10, 25, 0, 0): 16.0, datetime.datetime(2020, 11, 1, 0, 0): 142.0, datetime.datetime(2020, 11, 8, 0, 0): 27.0, datetime.datetime(2020, 11, 15, 0, 0): 40.0, datetime.datetime(2020, 11, 22, 0, 0): 40.0, datetime.datetime(2020, 11, 29, 0, 0): 69.0, datetime.datetime(2020, 12, 6, 0, 0): 68.0, datetime.datetime(2020, 12, 13, 0, 0): 66.0, datetime.datetime(2020, 12, 20, 0, 0): 79.0, datetime.datetime(2020, 12, 27, 0, 0): 102.0, datetime.datetime(2021, 1, 3, 0, 0): 123.0, datetime.datetime(2021, 1, 10, 0, 0): 80.0, datetime.datetime(2021, 1, 17, 0, 0): 80.0, datetime.datetime(2021, 1, 24, 0, 0): 70.0, datetime.datetime(2021, 1, 31, 0, 0): 60.0, datetime.datetime(2021, 2, 7, 0, 0): 48.0, datetime.datetime(2021, 2, 14, 0, 0): 32.0, datetime.datetime(2021, 2, 21, 0, 0): 18.0, datetime.datetime(2021, 2, 28, 0, 0): 14.0, datetime.datetime(2021, 3, 7, 0, 0): 16.0, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): 0.0, datetime.datetime(2020, 1, 1, 0, 0): 1250.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 11.0, datetime.datetime(2020, 5, 1, 0, 0): 15.0, datetime.datetime(2020, 6, 1, 0, 0): nan, datetime.datetime(2020, 7, 1, 0, 0): 12.0, datetime.datetime(2020, 8, 1, 0, 0): 35.0, datetime.datetime(2020, 9, 1, 0, 0): 44.0, datetime.datetime(2020, 10, 1, 0, 0): 66.0, datetime.datetime(2020, 12, 1, 0, 0): 341.0, datetime.datetime(2021, 1, 1, 0, 0): 577.0, datetime.datetime(2021, 2, 1, 0, 0): 154.0, datetime.datetime(2021, 3, 1, 0, 0): 33.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Wisconsin {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): nan, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): nan, datetime.datetime(2020, 3, 29, 0, 0): 12.0, datetime.datetime(2020, 4, 5, 0, 0): 16.0, datetime.datetime(2020, 4, 12, 0, 0): 12.0, datetime.datetime(2020, 4, 19, 0, 0): nan, datetime.datetime(2020, 4, 26, 0, 0): nan, datetime.datetime(2020, 5, 3, 0, 0): 16.0, datetime.datetime(2020, 5, 10, 0, 0): 10.0, datetime.datetime(2020, 5, 17, 0, 0): 20.0, datetime.datetime(2020, 5, 24, 0, 0): 11.0, datetime.datetime(2020, 5, 31, 0, 0): nan, datetime.datetime(2020, 6, 7, 0, 0): nan, datetime.datetime(2020, 6, 14, 0, 0): nan, datetime.datetime(2020, 6, 21, 0, 0): nan, datetime.datetime(2020, 6, 28, 0, 0): nan, datetime.datetime(2020, 7, 5, 0, 0): nan, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): 11.0, datetime.datetime(2020, 7, 26, 0, 0): nan, datetime.datetime(2020, 8, 2, 0, 0): 16.0, datetime.datetime(2020, 8, 9, 0, 0): 12.0, datetime.datetime(2020, 8, 16, 0, 0): 13.0, datetime.datetime(2020, 8, 23, 0, 0): 16.0, datetime.datetime(2020, 8, 30, 0, 0): 11.0, datetime.datetime(2020, 9, 6, 0, 0): 14.0, datetime.datetime(2020, 9, 13, 0, 0): 20.0, datetime.datetime(2020, 9, 20, 0, 0): 23.0, datetime.datetime(2020, 9, 27, 0, 0): 36.0, datetime.datetime(2020, 10, 4, 0, 0): 53.0, datetime.datetime(2020, 10, 11, 0, 0): 70.0, datetime.datetime(2020, 10, 18, 0, 0): 86.0, datetime.datetime(2020, 10, 25, 0, 0): 108.0, datetime.datetime(2020, 11, 1, 0, 0): 734.0, datetime.datetime(2020, 11, 8, 0, 0): 172.0, datetime.datetime(2020, 11, 15, 0, 0): 174.0, datetime.datetime(2020, 11, 22, 0, 0): 180.0, datetime.datetime(2020, 11, 29, 0, 0): 186.0, datetime.datetime(2020, 12, 6, 0, 0): 144.0, datetime.datetime(2020, 12, 13, 0, 0): 130.0, datetime.datetime(2020, 12, 20, 0, 0): 103.0, datetime.datetime(2020, 12, 27, 0, 0): 104.0, datetime.datetime(2021, 1, 3, 0, 0): 103.0, datetime.datetime(2021, 1, 10, 0, 0): 78.0, datetime.datetime(2021, 1, 17, 0, 0): 80.0, datetime.datetime(2021, 1, 24, 0, 0): 66.0, datetime.datetime(2021, 1, 31, 0, 0): 44.0, datetime.datetime(2021, 2, 7, 0, 0): 33.0, datetime.datetime(2021, 2, 14, 0, 0): 22.0, datetime.datetime(2021, 2, 21, 0, 0): 28.0, datetime.datetime(2021, 2, 28, 0, 0): 17.0, datetime.datetime(2021, 3, 7, 0, 0): nan, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): nan, datetime.datetime(2020, 1, 1, 0, 0): 2497.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 48.0, datetime.datetime(2020, 5, 1, 0, 0): 59.0, datetime.datetime(2020, 6, 1, 0, 0): 23.0, datetime.datetime(2020, 7, 1, 0, 0): 32.0, datetime.datetime(2020, 8, 1, 0, 0): 58.0, datetime.datetime(2020, 9, 1, 0, 0): 88.0, datetime.datetime(2020, 10, 1, 0, 0): 333.0, datetime.datetime(2020, 12, 1, 0, 0): 589.0, datetime.datetime(2021, 1, 1, 0, 0): 528.0, datetime.datetime(2021, 2, 1, 0, 0): 124.0, datetime.datetime(2021, 3, 1, 0, 0): 39.0, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Wyoming {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 0.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): 0.0, datetime.datetime(2020, 3, 22, 0, 0): 0.0, datetime.datetime(2020, 3, 29, 0, 0): 0.0, datetime.datetime(2020, 4, 5, 0, 0): 0.0, datetime.datetime(2020, 4, 12, 0, 0): nan, datetime.datetime(2020, 4, 19, 0, 0): nan, datetime.datetime(2020, 4, 26, 0, 0): 0.0, datetime.datetime(2020, 5, 3, 0, 0): 0.0, datetime.datetime(2020, 5, 10, 0, 0): 0.0, datetime.datetime(2020, 5, 17, 0, 0): nan, datetime.datetime(2020, 5, 24, 0, 0): 0.0, datetime.datetime(2020, 5, 31, 0, 0): 0.0, datetime.datetime(2020, 6, 7, 0, 0): nan, datetime.datetime(2020, 6, 14, 0, 0): nan, datetime.datetime(2020, 6, 21, 0, 0): 0.0, datetime.datetime(2020, 6, 28, 0, 0): 0.0, datetime.datetime(2020, 7, 5, 0, 0): 0.0, datetime.datetime(2020, 7, 12, 0, 0): 0.0, datetime.datetime(2020, 7, 19, 0, 0): nan, datetime.datetime(2020, 7, 26, 0, 0): 0.0, datetime.datetime(2020, 8, 2, 0, 0): nan, datetime.datetime(2020, 8, 9, 0, 0): 0.0, datetime.datetime(2020, 8, 16, 0, 0): nan, datetime.datetime(2020, 8, 23, 0, 0): 0.0, datetime.datetime(2020, 8, 30, 0, 0): nan, datetime.datetime(2020, 9, 6, 0, 0): nan, datetime.datetime(2020, 9, 13, 0, 0): nan, datetime.datetime(2020, 9, 20, 0, 0): nan, datetime.datetime(2020, 9, 27, 0, 0): nan, datetime.datetime(2020, 10, 4, 0, 0): nan, datetime.datetime(2020, 10, 11, 0, 0): nan, datetime.datetime(2020, 10, 18, 0, 0): nan, datetime.datetime(2020, 10, 25, 0, 0): 10.0, datetime.datetime(2020, 11, 1, 0, 0): 74.0, datetime.datetime(2020, 11, 8, 0, 0): 14.0, datetime.datetime(2020, 11, 15, 0, 0): 17.0, datetime.datetime(2020, 11, 22, 0, 0): 18.0, datetime.datetime(2020, 11, 29, 0, 0): 20.0, datetime.datetime(2020, 12, 6, 0, 0): 21.0, datetime.datetime(2020, 12, 13, 0, 0): 26.0, datetime.datetime(2020, 12, 20, 0, 0): 18.0, datetime.datetime(2020, 12, 27, 0, 0): nan, datetime.datetime(2021, 1, 3, 0, 0): 17.0, datetime.datetime(2021, 1, 10, 0, 0): 13.0, datetime.datetime(2021, 1, 17, 0, 0): nan, datetime.datetime(2021, 1, 24, 0, 0): nan, datetime.datetime(2021, 1, 31, 0, 0): 10.0, datetime.datetime(2021, 2, 7, 0, 0): nan, datetime.datetime(2021, 2, 14, 0, 0): nan, datetime.datetime(2021, 2, 21, 0, 0): nan, datetime.datetime(2021, 2, 28, 0, 0): nan, datetime.datetime(2021, 3, 7, 0, 0): nan, datetime.datetime(2021, 3, 14, 0, 0): nan, datetime.datetime(2021, 3, 21, 0, 0): 0.0, datetime.datetime(2021, 3, 28, 0, 0): 0.0, datetime.datetime(2020, 1, 1, 0, 0): 278.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): nan, datetime.datetime(2020, 5, 1, 0, 0): nan, datetime.datetime(2020, 6, 1, 0, 0): nan, datetime.datetime(2020, 7, 1, 0, 0): nan, datetime.datetime(2020, 8, 1, 0, 0): nan, datetime.datetime(2020, 9, 1, 0, 0): nan, datetime.datetime(2020, 10, 1, 0, 0): 25.0, datetime.datetime(2020, 12, 1, 0, 0): 83.0, datetime.datetime(2021, 1, 1, 0, 0): 80.0, datetime.datetime(2021, 2, 1, 0, 0): 23.0, datetime.datetime(2021, 3, 1, 0, 0): nan, datetime.datetime(2021, 4, 1, 0, 0): 0.0}
# Puerto Rico {datetime.datetime(2019, 12, 29, 0, 0): 0.0, datetime.datetime(2020, 1, 5, 0, 0): 0.0, datetime.datetime(2020, 1, 12, 0, 0): 0.0, datetime.datetime(2020, 1, 19, 0, 0): 0.0, datetime.datetime(2020, 1, 26, 0, 0): 0.0, datetime.datetime(2020, 2, 2, 0, 0): 0.0, datetime.datetime(2020, 2, 9, 0, 0): 0.0, datetime.datetime(2020, 2, 16, 0, 0): 0.0, datetime.datetime(2020, 2, 23, 0, 0): 0.0, datetime.datetime(2020, 3, 1, 0, 0): 15.0, datetime.datetime(2020, 3, 8, 0, 0): 0.0, datetime.datetime(2020, 3, 15, 0, 0): nan, datetime.datetime(2020, 3, 22, 0, 0): nan, datetime.datetime(2020, 3, 29, 0, 0): 10.0, datetime.datetime(2020, 4, 5, 0, 0): 11.0, datetime.datetime(2020, 4, 12, 0, 0): 10.0, datetime.datetime(2020, 4, 19, 0, 0): nan, datetime.datetime(2020, 4, 26, 0, 0): nan, datetime.datetime(2020, 5, 3, 0, 0): nan, datetime.datetime(2020, 5, 10, 0, 0): nan, datetime.datetime(2020, 5, 17, 0, 0): nan, datetime.datetime(2020, 5, 24, 0, 0): nan, datetime.datetime(2020, 5, 31, 0, 0): nan, datetime.datetime(2020, 6, 7, 0, 0): nan, datetime.datetime(2020, 6, 14, 0, 0): nan, datetime.datetime(2020, 6, 21, 0, 0): 0.0, datetime.datetime(2020, 6, 28, 0, 0): nan, datetime.datetime(2020, 7, 5, 0, 0): nan, datetime.datetime(2020, 7, 12, 0, 0): nan, datetime.datetime(2020, 7, 19, 0, 0): 16.0, datetime.datetime(2020, 7, 26, 0, 0): 18.0, datetime.datetime(2020, 8, 2, 0, 0): 25.0, datetime.datetime(2020, 8, 9, 0, 0): 46.0, datetime.datetime(2020, 8, 16, 0, 0): 33.0, datetime.datetime(2020, 8, 23, 0, 0): 19.0, datetime.datetime(2020, 8, 30, 0, 0): 29.0, datetime.datetime(2020, 9, 6, 0, 0): 46.0, datetime.datetime(2020, 9, 13, 0, 0): 28.0, datetime.datetime(2020, 9, 20, 0, 0): 31.0, datetime.datetime(2020, 9, 27, 0, 0): 39.0, datetime.datetime(2020, 10, 4, 0, 0): 31.0, datetime.datetime(2020, 10, 11, 0, 0): 22.0, datetime.datetime(2020, 10, 18, 0, 0): 23.0, datetime.datetime(2020, 10, 25, 0, 0): 23.0, datetime.datetime(2020, 11, 1, 0, 0): 241.0, datetime.datetime(2020, 11, 8, 0, 0): 47.0, datetime.datetime(2020, 11, 15, 0, 0): 59.0, datetime.datetime(2020, 11, 22, 0, 0): 78.0, datetime.datetime(2020, 11, 29, 0, 0): 71.0, datetime.datetime(2020, 12, 6, 0, 0): 88.0, datetime.datetime(2020, 12, 13, 0, 0): 74.0, datetime.datetime(2020, 12, 20, 0, 0): 63.0, datetime.datetime(2020, 12, 27, 0, 0): 52.0, datetime.datetime(2021, 1, 3, 0, 0): 47.0, datetime.datetime(2021, 1, 10, 0, 0): 40.0, datetime.datetime(2021, 1, 17, 0, 0): 32.0, datetime.datetime(2021, 1, 24, 0, 0): 38.0, datetime.datetime(2021, 1, 31, 0, 0): 30.0, datetime.datetime(2021, 2, 7, 0, 0): 20.0, datetime.datetime(2021, 2, 14, 0, 0): 24.0, datetime.datetime(2021, 2, 21, 0, 0): 14.0, datetime.datetime(2021, 2, 28, 0, 0): 11.0, datetime.datetime(2021, 3, 7, 0, 0): nan, datetime.datetime(2021, 3, 14, 0, 0): 11.0, datetime.datetime(2021, 3, 21, 0, 0): nan, datetime.datetime(2021, 3, 28, 0, 0): nan, datetime.datetime(2020, 1, 1, 0, 0): 1372.0, datetime.datetime(2020, 2, 1, 0, 0): 0.0, datetime.datetime(2020, 4, 1, 0, 0): 36.0, datetime.datetime(2020, 5, 1, 0, 0): 21.0, datetime.datetime(2020, 6, 1, 0, 0): nan, datetime.datetime(2020, 7, 1, 0, 0): 47.0, datetime.datetime(2020, 8, 1, 0, 0): 131.0, datetime.datetime(2020, 9, 1, 0, 0): 155.0, datetime.datetime(2020, 10, 1, 0, 0): 111.0, datetime.datetime(2020, 12, 1, 0, 0): 317.0, datetime.datetime(2021, 1, 1, 0, 0): 291.0, datetime.datetime(2021, 2, 1, 0, 0): 88.0, datetime.datetime(2021, 3, 1, 0, 0): 32.0, datetime.datetime(2021, 4, 1, 0, 0): nan}

# %% [markdown]
# ### Problem 9: Conclusion
#
# By the end of Thursday and turned in Tuesday, you should have the the ability to plot the following. Mine reflects optimized values. Your would have a flat line for $R_o$ and a simple relation between deaths and time.

# %%
# %reload_ext autoreload
from SEIRv2 import SEIR
# %matplotlib inline
seir = SEIR()
seir.plot_location("Pennsylvania")
